# %% [raw]
# ---
# description: Metric tracking and analysis tools
# output-file: metrics.html
# title: Metrics
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(PSNRMetric)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### PSNRMetric
#
# >      PSNRMetric (max_val, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(RMSEMetric)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L39){target="_blank" style="float:right; font-size:smaller"}
#
# ### RMSEMetric
#
# >      RMSEMetric (**kwargs)

# %%
#| echo: false
#| output: asis
show_doc(MAEMetric)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### MAEMetric
#
# >      MAEMetric (**kwargs)

# %%
#| echo: false
#| output: asis
show_doc(MSEMetric)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### MSEMetric
#
# >      MSEMetric (**kwargs)

# %%
#| echo: false
#| output: asis
show_doc(SSIMMetric)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### SSIMMetric
#
# >      SSIMMetric (spatial_dims=3, **kwargs)

# %% [markdown]
# ### Fourier Ring Correlation

# %% [markdown]
# #### Radial mask

# %%
#| echo: false
#| output: asis
show_doc(radial_mask)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### radial_mask
#
# >      radial_mask (r, cx=128, cy=128, sx=256, sy=256, delta=1)
#
# *Generate a radial mask.
#
# Returns:
#    - numpy.ndarray: Radial mask.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | r |  |  | Radius of the radial mask |
# | cx | int | 128 | X coordinate mask center |
# | cy | int | 128 | Y coordinate maske center |
# | sx | int | 256 | Size of the x-axis |
# | sy | int | 256 | Size of the y-axis |
# | delta | int | 1 | Thickness adjustment for the circular mask |

# %%
#| echo: false
#| output: asis
show_doc(get_radial_masks)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L92){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_radial_masks
#
# >      get_radial_masks (width, height)
#
# *Generates a set of radial masks and corresponding to spatial frequencies.
#
# Returns:
#     tuple: A tuple containing:
#         - numpy.ndarray: Array of radial masks.
#         - numpy.ndarray: Array of spatial frequencies corresponding to the masks.*
#
# |    | **Details** |
# | -- | ----------- |
# | width | Width of the image |
# | height | Height of the image |

# %% [markdown]
# #### Fourier ring correlation

# %%
#| echo: false
#| output: asis
show_doc(get_fourier_ring_correlations)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L125){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_fourier_ring_correlations
#
# >      get_fourier_ring_correlations (image1, image2)
#
# *Compute Fourier Ring Correlation (FRC) between two images.
#
# Returns:
#     tuple: A tuple containing:
#         - torch.Tensor: Fourier Ring Correlation values.
#         - torch.Tensor: Array of spatial frequencies.*
#
# |    | **Details** |
# | -- | ----------- |
# | image1 | First input image |
# | image2 | Second input image |

# %%
#| echo: false
#| output: asis
show_doc(FRCMetric)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/bioMONAI/blob/main/bioMONAI/metrics.py#L195){target="_blank" style="float:right; font-size:smaller"}
#
# ### FRCMetric
#
# >      FRCMetric (image1, image2)
#
# *Compute the area under the Fourier Ring Correlation (FRC) curve between two images.
#
# Returns:
#     - float: The area under the FRC curve.*
#
# |    | **Details** |
# | -- | ----------- |
# | image1 | First input image |
# | image2 | Second input image |

# %% [markdown]
# ---
